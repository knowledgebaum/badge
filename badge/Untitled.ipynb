# %%
from badgeModule import Badge, prepare_csv
from pathlib import Path
import pprint
import pandas as pd
import os

#badgeModule, runner.py, and test_badge should all be in the same directory.
#Enter the csv paths.



#Enter Symptom CSV Path Here
sympPath =  Path('data/ak_symptoms.csv')
#Enter Trigger CSV Path Here
trigPath =  Path('data/ak_triggers.csv')

###Test Path###
test = os.path.exists(sympPath)
print(test)

#################
### RUNNING SPACE ###
#################


combined_csv = prepare_csv(sympPath, trigPath)

print(combined_csv)

asaf = Badge(1, combined_csv)
asaf.get_user_stats()

#Print Output#


print('USER STATS **************')
pprint.pprint(asaf.show_user_stats_dict())
print('*************************')


print('Citizen Scientist Badge Level:' + str(asaf.get_rank_badge()))
print('Complex Badge: ' + str(asaf.get_complex_diet_badge()))
print('Archivist Badge; ' + str(asaf.get_archivist_badge()))
print('Coffee Badge; ' + str(asaf.get_coffee_badge()))
print('Lactose Badge: ' + str(asaf.get_lactose_badge()))
print('Lectin Badge: ' + str(asaf.get_lectin_badge()))
print('Gluten Badge: ' + str(asaf.get_gluten_badge()))


print('*********USER STATS AND BADGES***********')
pprint.pprint(asaf.create_table())


#You Can Output to CSV
#asaf.output_to_csv()
# Out:
# True
#                      ts         symptom  intensity  duration        day  \
# 0   2019-04-13 04:30:00             gas       35.0       0.0 2019-04-13
# 1   2019-04-12 08:45:00             gas       10.0       0.0 2019-04-12
# 2   2019-04-11 15:55:00             gas       60.0       0.0 2019-04-11
# 3   2019-04-11 02:20:00             gas       75.0     360.0 2019-04-11
# 4   2019-04-10 02:45:00             gas       75.0      60.0 2019-04-10
# 5   2019-04-09 07:05:00             gas       25.0       0.0 2019-04-09
# 6   2019-04-09 07:05:00      difficulty       55.0       0.0 2019-04-09
# 7   2019-04-09 07:05:00         urgency       15.0       0.0 2019-04-09
# 8   2019-04-09 07:05:00    constipation       50.0       0.0 2019-04-09
# 9   2019-04-09 07:05:00  incompleteness       80.0       0.0 2019-04-09
# 10  2019-04-09 00:35:00             gas       40.0       0.0 2019-04-09
# 11  2019-04-08 05:45:00             gas       25.0       0.0 2019-04-08
# 12  2019-04-07 16:20:00             gas       60.0       0.0 2019-04-07
# 13  2019-04-06 15:55:00             gas       35.0       0.0 2019-04-06
# 14  2019-04-05 15:50:00             gas       75.0       0.0 2019-04-05
# 15  2019-04-05 06:50:00             gas       75.0       0.0 2019-04-05
# 16  2019-04-04 07:40:00             gas       25.0       0.0 2019-04-04
# 17  2019-04-03 05:00:00             gas       60.0       0.0 2019-04-03
# 18  2019-04-01 06:25:00             gas       50.0       0.0 2019-04-01
# 19  2019-03-31 05:00:00             gas       90.0     180.0 2019-03-31
# 20  2019-03-31 05:00:00        bloating       90.0     180.0 2019-03-31
# 21  2019-03-30 05:30:00        bloating       65.0       0.0 2019-03-30
# 22  2019-03-30 05:30:00             gas       75.0       0.0 2019-03-30
# 23  2019-03-29 06:20:00             gas       60.0     280.0 2019-03-29
# 24  2019-03-28 04:40:00             gas       40.0       0.0 2019-03-28
# 25  2019-03-24 06:20:00             gas       75.0       0.0 2019-03-24
# 26  2019-03-24 19:00:00        bloating       70.0     165.0 2019-03-25
# 27  2019-03-24 19:00:00             gas       85.0     165.0 2019-03-25
# 28  2019-03-24 17:25:00             gas       15.0       0.0 2019-03-25
# 29  2019-03-23 06:00:00        bloating       65.0     270.0 2019-03-23
# ..                  ...             ...        ...       ...        ...
# 907 2019-03-16 06:35:00             NaN        NaN       NaN 2019-03-16
# 908 2019-03-16 02:30:00             NaN        NaN       NaN 2019-03-16
# 909 2019-03-15 22:15:00             NaN        NaN       NaN 2019-03-16
# 910 2019-03-15 16:15:00             NaN        NaN       NaN 2019-03-15
# 911 2019-03-14 07:10:00             NaN        NaN       NaN 2019-03-14
# 912 2019-03-31 08:45:00             NaN        NaN       NaN 2019-03-31
# 913 2019-03-23 00:20:00             NaN        NaN       NaN 2019-03-23
# 914 2019-03-18 06:00:00             NaN        NaN       NaN 2019-03-18
# 915 2019-04-10 04:10:00             NaN        NaN       NaN 2019-04-10
# 916 2019-04-10 04:10:00             NaN        NaN       NaN 2019-04-10
# 917 2019-04-09 05:10:00             NaN        NaN       NaN 2019-04-09
# 918 2019-04-09 05:10:00             NaN        NaN       NaN 2019-04-09
# 919 2019-04-08 03:45:00             NaN        NaN       NaN 2019-04-08
# 920 2019-04-07 02:00:00             NaN        NaN       NaN 2019-04-07
# 921 2019-04-07 02:00:00             NaN        NaN       NaN 2019-04-07
# 922 2019-04-05 02:00:00             NaN        NaN       NaN 2019-04-05
# 923 2019-04-05 02:00:00             NaN        NaN       NaN 2019-04-05
# 924 2019-04-02 05:30:00             NaN        NaN       NaN 2019-04-02
# 925 2019-04-02 05:30:00             NaN        NaN       NaN 2019-04-02
# 926 2019-03-30 21:30:00             NaN        NaN       NaN 2019-03-31
# 927 2019-03-29 02:45:00             NaN        NaN       NaN 2019-03-29
# 928 2019-03-29 02:45:00             NaN        NaN       NaN 2019-03-29
# 929 2019-03-23 21:45:00             NaN        NaN       NaN 2019-03-24
# 930 2019-03-22 03:30:00             NaN        NaN       NaN 2019-03-22
# 931 2019-03-22 03:30:00             NaN        NaN       NaN 2019-03-22
# 932 2019-03-20 03:30:00             NaN        NaN       NaN 2019-03-20
# 933 2019-03-20 03:30:00             NaN        NaN       NaN 2019-03-20
# 934 2019-03-17 23:10:00             NaN        NaN       NaN 2019-03-18
# 935 2019-03-16 18:30:00             NaN        NaN       NaN 2019-03-17
# 936 2019-04-08 23:20:00             NaN        NaN       NaN 2019-04-09
#
#            week       month            trigger
# 0    2019-04-07  2019-04-01                NaN
# 1    2019-04-07  2019-04-01                NaN
# 2    2019-04-07  2019-04-01                NaN
# 3    2019-04-07  2019-04-01                NaN
# 4    2019-04-07  2019-04-01          Metamucil
# 5    2019-04-07  2019-04-01                NaN
# 6    2019-04-07  2019-04-01                NaN
# 7    2019-04-07  2019-04-01                NaN
# 8    2019-04-07  2019-04-01                NaN
# 9    2019-04-07  2019-04-01                NaN
# 10   2019-04-07  2019-04-01                NaN
# 11   2019-04-07  2019-04-01          Metamucil
# 12   2019-04-07  2019-04-01                NaN
# 13   2019-03-31  2019-04-01                NaN
# 14   2019-03-31  2019-04-01                NaN
# 15   2019-03-31  2019-04-01                NaN
# 16   2019-03-31  2019-04-01                NaN
# 17   2019-03-31  2019-04-01                NaN
# 18   2019-03-31  2019-04-01                NaN
# 19   2019-03-31  2019-03-01                NaN
# 20   2019-03-31  2019-03-01                NaN
# 21   2019-03-24  2019-03-01                NaN
# 22   2019-03-24  2019-03-01                NaN
# 23   2019-03-24  2019-03-01                NaN
# 24   2019-03-24  2019-03-01                NaN
# 25   2019-03-24  2019-03-01                NaN
# 26   2019-03-24  2019-03-01                NaN
# 27   2019-03-24  2019-03-01                NaN
# 28   2019-03-24  2019-03-01                NaN
# 29   2019-03-17  2019-03-01                NaN
# ..          ...         ...                ...
# 907  2019-03-10  2019-03-01          Metamucil
# 908  2019-03-10  2019-03-01          Metamucil
# 909  2019-03-10  2019-03-01          Metamucil
# 910  2019-03-10  2019-03-01          Metamucil
# 911  2019-03-10  2019-03-01          Metamucil
# 912  2019-03-31  2019-03-01          happiness
# 913  2019-03-17  2019-03-01              angry
# 914  2019-03-17  2019-03-01               Love
# 915  2019-04-07  2019-04-01             biking
# 916  2019-04-07  2019-04-01      weightlifting
# 917  2019-04-07  2019-04-01      weightlifting
# 918  2019-04-07  2019-04-01             biking
# 919  2019-04-07  2019-04-01           runnning
# 920  2019-04-07  2019-04-01             biking
# 921  2019-04-07  2019-04-01      weightlifting
# 922  2019-03-31  2019-04-01             biking
# 923  2019-03-31  2019-04-01      weightlifting
# 924  2019-03-31  2019-04-01      weightlifting
# 925  2019-03-31  2019-04-01             biking
# 926  2019-03-31  2019-03-01             hiking
# 927  2019-03-24  2019-03-01      weightlifting
# 928  2019-03-24  2019-03-01             biking
# 929  2019-03-24  2019-03-01            walking
# 930  2019-03-17  2019-03-01             biking
# 931  2019-03-17  2019-03-01      weightlifting
# 932  2019-03-17  2019-03-01             biking
# 933  2019-03-17  2019-03-01      weightlifting
# 934  2019-03-17  2019-03-01            walking
# 935  2019-03-17  2019-03-01            walking
# 936  2019-04-07  2019-04-01  piroxicam olamine
#
# [937 rows x 8 columns]
# USER STATS **************
# {'first_entery ': Timestamp('2019-03-14 00:00:00'),
#  'last_entry': Timestamp('2019-04-15 00:00:00'),
#  'number_days_with_enteries': 33,
#  'total_enteries': 937,
#  'total_food_enteries': 937,
#  'total_symptom_enteries': 345}
# *************************
# Citizen Scientist Badge Level:6
# Complex Badge: True
# Archivist Badge; True
# Coffee Badge; True
# Lactose Badge: True
# Lectin Badge: True
# Gluten Badge: True
# *********USER STATS AND BADGES***********
# {'PK_ID': [1],
#  'User_ID': ['Asaf'],
#  'archivist_badge': True,
#  'coffee_badge': True,
#  'complex_diet_badge': True,
#  'first_entery': Timestamp('2019-03-14 00:00:00'),
#  'last_entery': Timestamp('2019-04-15 00:00:00'),
#  'rank_badge': 6,
#  'tot_entery_stat': 937,
#  'tot_symp_stat': 345,
#  'tot_trig_stat': 937}
